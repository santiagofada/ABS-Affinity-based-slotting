# %%
from abs_affinity_based_slotting.data.loaders import WarehouseDataLoader

loader = WarehouseDataLoader("../data/raw")
dataset = loader.load_all()

coordinates = dataset.coordinates
distances = dataset.distances
initial_stock = dataset.initial_stock
picking_events = dataset.picking_events
replenishment_events = dataset.replenishment_events
